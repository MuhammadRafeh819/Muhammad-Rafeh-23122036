# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadRafeh819/Muhammad-Rafeh-23122036/blob/main/Rafeh_Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai

# %%
from google import genai


# instead of removing api key i actually stored my keys in colab secrets....
from google.colab import userdata

# we can access our api keys using userdata.get("using secret name")
API_KEY = userdata.get("Gemini_key")
client = genai.Client(api_key=API_KEY)


print("Gemini Chatbot (type 'exit' to quit)\n")

# Chat loop
while True:
    user_input = input("You: ")

    # Exit condition
    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye 👋")
        break

    # Send input to Gemini
    response = client.models.generate_content(
        model="models/gemini-3.6-flash",
        contents=user_input
    )

    # Print response
    print("Chatbot:", response.text)
# Out:
# Gemini Chatbot (type 'exit' to quit)
#
# You: where is dehli located
# Chatbot: **Delhi** (officially the National Capital Territory of Delhi) is located in **northern India**.
#
# Here are the specific details of its location:
#
# * **Country:** India (in South Asia)
# * **Region:** Northern India, situated in the Gangetic plains.
# * **Borders:** It is surrounded by the state of **Haryana** on three sides (north, west, and south) and borders the state of **Uttar Pradesh** to the east.
# * **Key Landmarks/Geography:** It sits along the banks of the **Yamuna River**.
# * **Geographic Coordinates:** Approximately 28.61° N latitude and 77.20° E longitude.
#
# *Note: **New Delhi**, the official capital city of India, is a district located entirely within the larger metropolis of Delhi.*
# You: exit
# Chatbot: Goodbye 👋
